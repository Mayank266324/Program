# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r"D:\Programming\Datasets\Wine_Quality.csv")
data.isnull().sum()
# Out:
# type                     0
# fixed acidity           10
# volatile acidity         8
# citric acid              3
# residual sugar           2
# chlorides                2
# free sulfur dioxide      0
# total sulfur dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
(data.isnull().sum()/data.shape[0])*100
# Out:
# type                    0.000000
# fixed acidity           0.153917
# volatile acidity        0.123134
# citric acid             0.046175
# residual sugar          0.030783
# chlorides               0.030783
# free sulfur dioxide     0.000000
# total sulfur dioxide    0.000000
# density                 0.000000
# pH                      0.138525
# sulphates               0.061567
# alcohol                 0.000000
# quality                 0.000000
# dtype: float64

# %%
data.isnull().sum().sum()
# Out:
# np.int64(38)

# %%
data.notnull().sum().sum()
# Out:
# np.int64(84423)

# %%
sns.heatmap(data.isnull())
plt.show()
